# %%
import fiftyone as fo
import fiftyone.zoo as foz

# %%
dataset = foz.load_zoo_dataset(
    "coco-2017",
    split="train"
)
# Out:
# ...
# Found annotations at '/home/smedar/fiftyone/coco-2017/raw/instances_train2017.json'
# ...
#  100% |████|  144.1Gb/144.1Gb [5.3m elapsed, 0s remaining, 520.1Mb/s]
# Extracting images to '/home/smedar/fiftyone/coco-2017/train/data'
# Writing annotations to '/home/smedar/fiftyone/coco-2017/train/labels.json'
# Dataset info written to '/home/smedar/fiftyone/coco-2017/info.json'
# Loading 'coco-2017' split 'train'
#  100% |███████████| 118287/118287 [4.7m elapsed, 0s remaining, 563.7 samples/s]
# Dataset 'coco-2017-train' created
